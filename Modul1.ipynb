# %% [markdown]
# <a href="https://colab.research.google.com/github/YossyF/PCVK_GENAP_2023/blob/main/Modul1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **MODUL1 - Penggunaan Github dan Google Colaboratory, Membaca dan Menampilkan Citra**

# %%
#Langkah 1
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow #for image display
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pylab as plt

# %%
# LANGKAH 2
# Membuat list untuk menyimpan url dari beberapa image
urls = ["https://i.postimg.cc/SsDMQ75y/IMG20220930132459.jpg"]
# baca dan tampilkan image
# loop pada tiap url image, beberapa image dapat disimpan pada list
for url in urls:
  image = io.imread(url)                          #read image
  image = cv.resize(image, (0,0), fx=0.5, fy=0.5)     #resize image to half size
  image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)  #convert color to RGB
  final_frame = cv.hconcat((image, image_2))      #concatenate image
  cv2_imshow(final_frame)                         #show image
  print('\n')
# Out:
# <PIL.Image.Image image mode=RGB size=1068x400 at 0x7F7B6252DC70>

# %%
# LANGKAH 3
# Melihat ukuran file image
tinggi = image_2.shape[0]
lebar = image_2.shape[1]
print("resolusi image: tinggi x lebar = ",tinggi," x ",lebar)
cv2_imshow(image_2)
# Out:
# resolusi image: tinggi x lebar =  400  x  534
# <PIL.Image.Image image mode=RGB size=534x400 at 0x7F7B64575760>

# %%
# LANGKAH 4
# Mengakses pixel dengan memberi garis diagonal menyilang
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# membuat garis horizontal di tengah image
for y in range (lebar):
  image_3[int((tinggi)/2),y] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=1068x400 at 0x7F7B64575DF0>

# %% [markdown]
# **PERTANYAAN**
#
# **1. Jelaskan, mengapa pada modul praktikum ini eksekusi kode Python dilakukan menggunakan Google Colab?**
#
# Karena Google Colab adalah sebuah software compiler dan editor bahasa pemrograman python secara online (berbasis cloud) sehingga dengan menggunakan software ini tidak perlu adanya proses instalasi dan konfigurasi library pada perangkat komputer dan tidak memakan sumber daya pada komputer. Selain itu dengan menggunakan Google Colab memungkinkan fleksibilitas yang tinggi karena dapat diakses melalui web dan internet dan juga memiliki integrasi yang mudah terhadap Google Drive dan Github.
#
# **2. Jelaskan mengenai kegunaan setiap library pada praktikum langkah ke delapan? Apakah semua library tersebut harus digunakan dalam praktikum sesi ini?**
#
# *   Numpy : digunakan untuk data sains ataupun komputasi numerik misal seperti menghitung operasi matematika dan array
# *   Pandas : digunakan untuk menganalisis data serta membangun sebuah machine learning
# *   CV2 : digunakan untuk memanggil modul opencv untuk proses input,simpan dan menampilkan citra/image (pengolahan citra)
# *   Skimage : digunakan untuk pemrosesan gambar dan visi komputer.
# *   PIL : digunakan untuk melakukan operasi dasar pada gambar seperti mengubah ukuran, rotasi, membuat thumbnail, mengkonversi antara format file yang berbeda, dll.
# *   Matplotlib : digunakan untuk menampilkan visualisasi grafik ataupun gambar
#
# **3.Pada uji coba langkah ke-9 terdapat potongan kode program sebagai berikut :** ![download.png](data:image/png;base64,...) **Apa kegunaan kode program tersebut? dan apa pengaruhnya jika tidak dilakukan?**
#
# Kode program tersebut digunakan untuk meresize ukuran citra atau mengubah ukuran gambar menjadi setengahnya. Jika tidak dilakukan maka, ukuran citra menjadi ukuran yang sebenarnya
#
# **4. Perhatikan potongan kode program berikut:**
# ![image.png](data:image/png;base64,...)
# **Apakah kegunaan kode [255,255,255] ? Jelaskan!**
#
# Kode tersebut digunakan untuk membuat garis horizontal di tengah image berwarna putih. Hal ini berdasarkan citra berwarna RGB ynag memiliki 3 level warna yaitu red = 255, green = 255 dan blue = 255.
#
# **5. Jelaskan keterkaitan antara pixel dan juga resolusi gambar yang tinggi ataupun rendah!**
#
# Pixel atau Picture Element adalah elemen terkecil citra digital. Sedangkan resolusi merupakan jumlah pixel atau kerapatan pixel yang tersusun dalam suatu gambar digital. Semakin tinggi resolusi maka akan semakin banyak pixel yang ada sehingga gambar akan semakin detail dan kualitas akan semakin bagus.

# %% [markdown]
# **Tugas**
#
# Membuat garis vertikal dan garis menyilang diagonal pada image keluaran

# %%
# GARIS VERTIKAL dan DIAGONAL
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# membuat garis vertikal di tengah image
for x in range (tinggi):
  image_3[x, int((lebar)/2)] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)

# membuat garis diagonal
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

line1_1 = (0,0)
line1_2 = (534,400)

line2_1 = (534,0)
line2_2 = (0,400)

cv.line(image_3, line1_1, line1_2, (255,255,255))
cv.line(image_3, line2_1, line2_2, (255,255,255))

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=1068x400 at 0x7F7B6252D790>
# <PIL.Image.Image image mode=RGB size=1068x400 at 0x7F7B6252D130>
