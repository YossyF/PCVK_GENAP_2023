# %% [markdown]
# <a href="https://colab.research.google.com/github/YossyF/PCVK_GENAP_2023/blob/main/Modul2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **MODUL2 - Penggunaan Numpy dan OpenCV serta Pengenalan Aplikasi-aplikasi Pengolahan Citra**

# %%
from google.colab import drive


# Accessing my google drive
drive.mount('/content/drive')

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/Data Center/Documents/Kuliah/Semester 6/Pengolaan CItra/Gambar/Yossy_Firmansyah.jpg')
plt.imshow(img)

# %%
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
plt.imshow(img3)

# %%
img_gray = cv.imread('/content/drive/MyDrive/Data Center/Documents/Kuliah/Semester 6/Pengolaan CItra/Gambar/Yossy_Firmansyah.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
plt.imshow(img_gray, cmap='magma')

# %%
img4 = cv.resize(cv.cvtColor(img,cv.COLOR_BGR2RGB), (512,1024))
plt.imshow(img4)

# %%
img5 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)

#tampilkan plot dengan ukuran canvas yang lebih besar
fig = plt.figure(figsize=(10,10))   #ubah sesuai kebutuhan
ax = fig.add_subplot(111)
ax.imshow(img5)

# %%
black_img = np.zeros(shape=(512,512,3),dtype=np.int16)
plt.imshow(black_img)

# %%
#perhatikan koordinat titik pt1 dan pt2 , pojok kiri atas dan pojok kanan bawah
cv.rectangle(black_img,pt1=(384,0),pt2=(510,150),color=(0,255,0),thickness=10)
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(200,200),pt2=(300,300),color=(0,0,255),thickness=15)
plt.imshow(black_img)

# %%
cv.circle(black_img,center=(100,100),radius=50,color=(255,0,0),thickness=8)
plt.imshow(black_img)

# %%
cv.line(black_img,pt1=(0,0),pt2=(512,512),color=(255,255,255),thickness=5)
plt.imshow(black_img)

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img,text='Hello',org=(10,500),fontFace=font,fontScale=4,color=(255,255,0),thickness=2,lineType=cv.LINE_AA)
plt.imshow(black_img)

# %%
black_img2=np.zeros(shape=(512,512,3),dtype=np.int32)
plt.imshow(black_img2)

# %%
#inisialisasi numpy array dengan type data int32
vertices = np.array([[100,300],[200,200],[400,300],[200,400]],dtype=np.int32)
vertices

# %%
#reshape array
pts = vertices.reshape((-1,1,2)) #nilai 2 untuk menunjukkan bahwa tiap titik dibuat 3 channel yang mewakili RGB
pts

# %%
#penambahan polyline pada black image kedua
cv.polylines(black_img2,[pts],isClosed=True,color=(255,0,0),thickness=5)
plt.imshow(black_img2)

# %% [markdown]
# # **PERTANYAAN**
#
# **1. Apakah perbedaan gambar yang ditampilkan tanpa dan dengan matplotlib?**
#
# Matplotlib adalah library untuk membuat visualisasi data plotting seperti histogram, bar graph, plots, error graphic, scatterplot dan lain-lain.
#
# **Berikut ini** perbedaan tampilan dengan **matplotlib** dan **tanpa matplotlib**.

# %% [markdown]
# **Mengguanakan matplotlib**

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/Data Center/Documents/Kuliah/Semester 6/Pengolaan CItra/Gambar/Yossy_Firmansyah.jpg')
plt.imshow(img) #mengguanakan plotlib

# %% [markdown]
# **Tanpa mengguanakan Matplotlib**

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/Data Center/Documents/Kuliah/Semester 6/Pengolaan CItra/Gambar/Yossy_Firmansyah.jpg')
cv2_imshow(img) #tanpa mengguanakan plotlib

# %% [markdown]
# **2. Apakah perbedaan dan pengaruhnya pembuatan black image antara tipe data int16 dan int32?**
#
# Perbedaan pembuatan black image antara tipe data int16 dan int32 adalah pada penyimpanan dan rentang nilai yang dapat ditampung. Tipe data int16 adalah tipe data 16-bit sedangkan tipe data int32 adalah tipe data 32-bit. Semakin besar bit maka semakin besar juga penyimpanan yang diperlukan

# %% [markdown]
# **3. Jelaskan tentang angka-angka yang terdapat pada reshape((-1,1,2))**
#
# **pts = verticies.reshape((-1,1,2))**
#
# Angka-angka yang terdapat pada reshape((-1,1,2)) adalah fungsi reshape dari library Numpy yang digunakan untuk mengubah bentuk array 'verticies' menjadi array 2D. Dalam kasus objek 3D, setiap baris pada array vertices merepresentasikan sebuah vertex dengan tiga koordinat (x, y, z), sehingga setelah direshape, array tersebut akan memiliki 2 baris sesuai jumlah vertex dan 1 kolom sesuai jumlah koordinat untuk setiap vertex.

# %% [markdown]
# **4. Apakah kegunaan "google.colab.patches import cv2_imshow" pada potongan kode berikut**
#
# **from google.colab.patches import cv2_imshow**
#
# **from skimage import io**
#
# "google.colab.patches import cv2_imshow" adalah perintah yang digunakan untuk menampilkan gambar dengan mengimpor modul openCV dan menampilkan gambar pop up dengan perintah "cv2_imshow".

# %% [markdown]
# **5. Apakah kegunaan “skimage impot io” pada potongan kode soal nomor 4**
#
# Kegunaan dari skimage.io adalah untuk memproses yaitu membaca dan menulis gambar dalam berbagai format

# %% [markdown]
# # **TUGAS**

# %% [markdown]
# **1. Tampilkan image dalam chaneel Red-Green dan Green-Blue saja|**

# %%
# Untuk Red Green
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
img3[:,:,2] = 0
plt.imshow(img3)

# %%
# Untuk Green Blue
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
img3[:,:,0] = 0
plt.imshow(img3)

# %% [markdown]
# **2. Tampilkan baris ke 10-100, kolom 10-100!**

# %%
plt.imshow(img[10:100, 10:100])

# %% [markdown]
# **3. Tampilkan image baris ke 5-30, semua kolom, channel Green saja!**

# %%
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
img3[:,:,(0,2)] = 0
plt.imshow(img3[5:30])

# %% [markdown]
# **4. Buat 5 kotak berbagai ukuran dan warna yang berbeda dalam satu image. disarankan menggunakan bilangan acak/random**

# %%
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
cv.rectangle(img3,pt1=(3000,500),pt2=(3200,2500),color=(255,0,0),thickness=50)
cv.rectangle(img3,pt1=(1000,1000),pt2=(2200,0),color=(0,255,0),thickness=50)
cv.rectangle(img3,pt1=(2400,1000),pt2=(1700,3000),color=(0,0,255),thickness=50)
cv.rectangle(img3,pt1=(1300,1500),pt2=(200,3000),color=(0,255,255),thickness=50)
cv.rectangle(img3,pt1=(4000,1500),pt2=(3000,3000),color=(255,255,255),thickness=50)
plt.imshow(img3)

# %% [markdown]
# **5. Tampilkan image dengan posisi terbalik!**

# %%
img = cv.imread('/content/drive/MyDrive/Data Center/Documents/Kuliah/Semester 6/Pengolaan CItra/Gambar/Yossy_Firmansyah.jpg')
img_flip = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB), 0)
plt.imshow(img_flip)

# %% [markdown]
# **6. Buat rectangle dan circle pada bagian wajah**

# %%
img = cv.imread('/content/drive/MyDrive/Data Center/Documents/Kuliah/Semester 6/Pengolaan CItra/Gambar/Yossy_Firmansyah_2.jpg')
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
cv.circle(img3, (1400,1850), 350, (0,255,0), 50)
cv.rectangle(img3,pt1=(1800,1500),pt2=(1000,2200),color=(255,0,0),thickness=50)
plt.imshow(img3)

# %% [markdown]
# **7. Buat rectangle pada bagian sudut bawah kiri channel B pada color space RGB pada gambar**

# %%
img = cv.imread('/content/drive/MyDrive/Data Center/Documents/Kuliah/Semester 6/Pengolaan CItra/Gambar/Yossy_Firmansyah_2.jpg')
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
img3[:,:,(0,1)] = 0
cv.rectangle(img3,pt1=(100,3900),pt2=(800,3200),color=(255,0,0),thickness=50)
plt.imshow(img3)
